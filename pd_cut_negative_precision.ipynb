# %% [markdown]
# http://stackoverflow.com/questions/32552027/with-pandas-cut-how-do-i-get-integer-bins-and-avoid-getting-a-negative-lowe

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style='white', font_scale=1.3)
# %matplotlib inline

df = pd.DataFrame(range(0,389,8)[:-1], columns=['value'])

# %% [markdown]
# ### pd.cut()

# %%
df['binned_df_pd'] = pd.cut(df.value, bins=7, precision=0, include_lowest=True)
sns.pointplot(x='binned_df_pd', y='value', data=df)
plt.xticks(rotation=30, ha='right')
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), <a list of 7 Text xticklabel objects>)

# %% [markdown]
# ### np.histogram()

# %%
import numpy as np

bin_counts, edges = np.histogram(df.value, bins=7)
w

df['binned_df_np'] = pd.cut(df.value, bins=edges, include_lowest=True)

sns.pointplot(x='binned_df_np', y='value', data=df)
plt.xticks(rotation=30, ha='right')
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), <a list of 7 Text xticklabel objects>)

# %% [markdown]
# ### pd.cut(right=False)

# %%
df['binned_df_pd'] = pd.cut(df.value, bins=7, precision=0, include_lowest=True, right=False)
sns.pointplot(x='binned_df_pd', y='value', data=df)
plt.xticks(rotation=30, ha='right')
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]), <a list of 7 Text xticklabel objects>)
